# %% [markdown]
# # Aufgabe heute:
# # Sie messen Sensor- Signale mit dem Oszilloskop
# #### Darstellung 1: Oszilloskop
#
#
# <img src="https://tdupb.github.io/oscilloscope.PNG" />
#
#
# ### Alle heutigen Signale sind "harmonische Schwingungen." (unendlich und gleichmäßig)
# ### Schwingungen entstehen in vielen Situationen und haben zunächst folgende Größen zur Beschreibung:
#
# * Amplitude
# * Frequenz bzw. Periodendauer
# * Phasenverschiebung
#
# #### A) Die Amplitude :
# beschreibt wie stark die Schwingung vom Nullpunkt bis zum (+/-) Maximum in y- Richtung *ausgelenkt* wird. Daher kann man auch von der **maximalen Auslenkung** sprechen.
# #### Eine Eselsbrücke könnte der "Amplifier" in der Tontechnik/Stereo-Anlage sein. Der "Amplifier" ist ein  "Verstärker." Er verstärkt in diesem Fall das Audiosignal, welches eine "Box" ansteuert.
#
# #### Darstellung 2: Auslenkung einer Muskibox durch Schalldruck als Funktionskurve fortlaufend
#
# <img src="https://tdupb.github.io/amp.gif" />
#
#
# #### B) Die Frequenz  und die Periodendauer:
# beschreibt wie oft in einem Zeitraum "hin und her" , "hoch und runter" geschwungen wurde. Wenn beispielsweise in einer Sekunde ein Pendel 2 mal "hin und her" geschwungen ist, dann ist die $~Frequenz~des~Pendels~f = \frac{2~ Schwingungen}{pro~Sekunde} = 2 \frac{1}{s} = 2~Hertz~$
#
# Die Frequenz ist der Kehrwert der Periodendauer. $~Die~ Periodendauer ~ T= \frac{1} {f}~$ wäre also bei dem beschriebenen  Fall des Pendels $~T = 0,5 sec.$
#
# #### Darstellung 3: Frequenzerhöhung in Hertz über eine Sekunde
#
#
# <img src="https://tdupb.github.io/frequency.gif" />
#
# #### C) Die Phasenverschiebung:
# Beschreibt den Startpunkt einer Schwingung auf dem Einheitskreis. Die Position einer Schwingung bzw. der Funktionswert kann entweder über die Sinus- oder Cosinusfunktion bestimmt werden.
#
# Wenn beide Funktionswerte fortlaufend dartgestellt werden könnte man sagen: "Der Cosinus hat sein Maximum 90° vor dem Sinus." oder wenn es gemessene Signale wären: "Die beiden Signale sind um 90° verschoben."
#
# Eine sinnvolle Angabe über die Verschiebung findet nur zwischen dem Anfangspunkt und Endpunkt einer Schwingung statt. Eine Angabe wie +90° ist gleich bedeutend mit - 270°.
#
#
#
# #### Darstellung 4: sinus und cosinus Winkelverhältnisse auf dem Kreisumfang
#
# <img src="https://tdupb.github.io/sincos.gif" />
# Je nach Darstellung und Anwendung wird auf der x-Achse:
#
# * der Mittelpunktswinkel: $~0°-360°~$,
# * der "zurückgelegte Weg" $~U=2*\pi*r~$ auf dem "Einheitskreis" Radius 1--> Kreiszahl Pi $~\pi ~ von ~0-2~\pi ~$
# * oder die Zeit: $~t ~in ~sec.~$
# angezeigt.
# #### Darstellung 5: Die Funktionswerte y= f(x)=sin(x)  mit dem Mittelpunktswinkel als x-Wert einer periodischen Bewegung.
#
# <img src="https://media.giphy.com/media/NKLdcqhwo2f8A/giphy.gif" />
#
#
# ### Nun zur Simulation: Öffnen Sie "Schwingung1.ipynb" aus dem Hauptordner des Github Repository.
#
# #### Ergründen Sie in 5 min. freier Arbeitsphase alle Funktionen und notieren Sie ggf. Fragen und Anmerkungen.
#
# #### Bearbeiten Sie das ausgeteilte Aufgabenblatt.
